# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots

# %%
# data reading

# %%
meta=pd.read_csv("Meta Dataset.xls")
meta
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2012-05-18   42.049999   45.000000   38.000000   38.230000   38.189480
# 1     2012-05-21   36.529999   36.660000   33.000000   34.029999   33.993931
# 2     2012-05-22   32.610001   33.590000   30.940001   31.000000   30.967144
# 3     2012-05-23   31.370001   32.500000   31.360001   32.000000   31.966084
# 4     2012-05-24   32.950001   33.209999   31.770000   33.029999   32.994991
# ...          ...         ...         ...         ...         ...         ...
# 3023  2024-05-24  467.619995  479.850006  466.299988  478.220001  478.220001
# 3024  2024-05-28  476.579987  480.859985  474.839996  479.920013  479.920013
# 3025  2024-05-29  474.660004  479.850006  473.700012  474.359985  474.359985
# 3026  2024-05-30  471.670013  471.730011  464.709991  467.049988  467.049988
# 3027  2024-05-31  465.799988  469.119995  454.459991  466.829987  466.829987
#
#          Volume
# 0     573576400
# ...

# %%
meta["Date"]=pd.to_datetime(meta["Date"])
meta.head(10)
# Out:
#         Date       Open       High        Low      Close  Adj Close     Volume
# 0 2012-05-18  42.049999  45.000000  38.000000  38.230000  38.189480  573576400
# 1 2012-05-21  36.529999  36.660000  33.000000  34.029999  33.993931  168192700
# 2 2012-05-22  32.610001  33.590000  30.940001  31.000000  30.967144  101786600
# 3 2012-05-23  31.370001  32.500000  31.360001  32.000000  31.966084   73600000
# 4 2012-05-24  32.950001  33.209999  31.770000  33.029999  32.994991   50237200
# 5 2012-05-25  32.900002  32.950001  31.110001  31.910000  31.876179   37149800
# 6 2012-05-29  31.480000  31.690001  28.650000  28.840000  28.809433   78063400
# 7 2012-05-30  28.700001  29.549999  27.860001  28.190001  28.160122   57267900
# 8 2012-05-31  28.549999  29.670000  26.830000  29.600000  29.568628  111639200
# 9 2012-06-01  28.889999  29.150000  27.389999  27.719999  27.690619   41855500

# %%
meta.shape
# Out:
# (3028, 7)

# %%
meta.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
meta.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
meta.corr()
# Out:
#                Date      Open      High       Low     Close  Adj Close  \
# Date       1.000000  0.856540  0.858577  0.855561  0.856988   0.856886
# Open       0.856540  1.000000  0.999782  0.999760  0.999519   0.999519
# High       0.858577  0.999782  1.000000  0.999719  0.999777   0.999777
# Low        0.855561  0.999760  0.999719  1.000000  0.999787   0.999786
# Close      0.856988  0.999519  0.999777  0.999787  1.000000   1.000000
# Adj Close  0.856886  0.999519  0.999777  0.999786  1.000000   1.000000
# Volume    -0.350145 -0.377529 -0.373654 -0.381900 -0.378046  -0.377980
#
#              Volume
# Date      -0.350145
# Open      -0.377529
# High      -0.373654
# Low       -0.381900
# Close     -0.378046
# Adj Close -0.377980
# Volume     1.000000

# %%
fig=make_subplots(rows=1,cols=1)
fig.add_trace(
    go.Scatter(x=meta["Date"],y=meta["Volume"],name="Volume")
)
fig.update_layout(
    title='Meta Volume Over Time',
    xaxis_title='Date',
    yaxis_title='Volume',
    showlegend=True
)
fig.show()
# Out:
# C:\Users\SMARTECH\anaconda3\Lib\site-packages\_plotly_utils\basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %%
fig=make_subplots(rows=1,cols=1)
fig.add_trace(
    go.Scatter(x=meta["Date"],y=meta["Close"],name="Close Price")
)
fig.update_layout(
    title='Meta Stock Price Over Time',
    xaxis_title='Date',
    yaxis_title='Close Price',
    showlegend=True
)
fig.show()

# %%
meta["Date"]=pd.to_datetime(meta["Date"])
meta["Year"]=meta["Date"].dt.year
meta["Day"]=meta["Date"].dt.day
meta["Month"]=meta["Date"].dt.month
meta_new=meta.drop(["Date"],axis=1)
meta_new.head(10)
# Out:
#         Open       High        Low      Close  Adj Close     Volume  Year  \
# 0  42.049999  45.000000  38.000000  38.230000  38.189480  573576400  2012
# 1  36.529999  36.660000  33.000000  34.029999  33.993931  168192700  2012
# 2  32.610001  33.590000  30.940001  31.000000  30.967144  101786600  2012
# 3  31.370001  32.500000  31.360001  32.000000  31.966084   73600000  2012
# 4  32.950001  33.209999  31.770000  33.029999  32.994991   50237200  2012
# 5  32.900002  32.950001  31.110001  31.910000  31.876179   37149800  2012
# 6  31.480000  31.690001  28.650000  28.840000  28.809433   78063400  2012
# 7  28.700001  29.549999  27.860001  28.190001  28.160122   57267900  2012
# 8  28.549999  29.670000  26.830000  29.600000  29.568628  111639200  2012
# 9  28.889999  29.150000  27.389999  27.719999  27.690619   41855500  2012
#
#    Day  Month
# 0   18      5
# 1   21      5
# 2   22      5
# 3   23      5
# 4   24      5
# 5   25      5
# 6   29      5
# 7   30      5
# ...

# %%
plt.bar(meta["Year"],meta["High"])
plt.xlabel("Year")
plt.ylabel("Highest Value")
plt.title("Highest Value per Year")
plt.show()

# %%
# relation beteween adj close and close.This graph show that nthere no big difference between them.

# %%
plt.scatter(meta_new["Adj Close"],meta_new["Close"])
plt.xlabel("Adj close")
plt.ylabel("Close")
plt.title("Adj close vs Close")
plt.show()

# %%
# Group the data by year
yearly_prices = meta.groupby('Year')
yearly_prices.first()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# Year
# 2012 2012-05-18   42.049999   45.000000   38.000000   38.230000   38.189480
# 2013 2013-01-02   27.440001   28.180000   27.420000   28.000000   27.970324
# 2014 2014-01-02   54.830002   55.220001   54.189999   54.709999   54.652012
# 2015 2015-01-02   78.580002   78.930000   77.699997   78.449997   78.366852
# 2016 2016-01-04  101.949997  102.239998   99.750000  102.220001  102.111656
# 2017 2017-01-03  116.029999  117.839996  115.510002  116.860001  116.736145
# 2018 2018-01-02  177.679993  181.580002  177.550003  181.419998  181.227707
# 2019 2019-01-02  128.990005  137.509995  128.559998  135.679993  135.536194
# 2020 2020-01-02  206.750000  209.789993  206.270004  209.779999  209.557648
# 2021 2021-01-04  274.779999  275.000000  265.200012  268.940002  268.654968
# 2022 2022-01-03  338.299988  341.079987  337.190002  338.540009  338.181183
# ...

# %%
yearly_prices_mean = meta.groupby('Year')[["Open","Close"]].mean().reset_index()
yearly_prices_mean
# Out:
#     Year        Open       Close
# 0   2012   24.799613   24.673097
# 1   2013   35.476429   35.481151
# 2   2014   68.763968   68.762341
# 3   2015   88.749405   88.772857
# 4   2016  117.081071  117.035873
# 5   2017  156.481076  156.576175
# 6   2018  171.472948  171.510956
# 7   2019  181.566547  181.637500
# 8   2020  234.348696  234.550870
# 9   2021  321.104603  321.166230
# 10  2022  180.239004  180.187690
# 11  2023  260.879041  261.424280
# 12  2024  459.710000  460.209715

# %%
fig = px.bar(yearly_prices_mean, x='Year', y=['Open', 'Close'], barmode='group', title='Meta Stock Price Open Close Comparison by Year')
fig.show()

# %%
Low_High_mean = meta.groupby('Year')[["Low","High"]].mean().reset_index()
Low_High_mean
# Out:
#     Year         Low        High
# 0   2012   24.195871   25.300903
# 1   2013   34.930159   36.045040
# 2   2014   67.830199   69.639524
# 3   2015   87.762778   89.683373
# 4   2016  115.865873  118.091706
# 5   2017  155.347012  157.557530
# 6   2018  169.303148  173.613347
# 7   2019  179.648889  183.482539
# 8   2020  230.790040  237.939922
# 9   2021  317.408094  325.005357
# 10  2022  176.878407  183.843068
# 11  2023  257.758320  264.768320
# 12  2024  454.078571  465.620666

# %%
fig = px.bar(Low_High_mean, x='Year', y=['Low', 'High'], barmode='group', title='Meta Stock Price Highest Lowest Comparison by Year')
fig.show()

# %%
# model fitting

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
x=meta_new.drop(["Volume"],axis=1)
y=meta_new["Volume"]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Model training and evaluation
models = {
    'Linear Regression': LinearRegression(),
    'Random Forest': RandomForestRegressor(random_state=42),
    "decision_tree":DecisionTreeRegressor(),
    "svr":SVR(),
    "knn":KNeighborsRegressor(n_neighbors=5)
}

# %%
results=[]
for name, model in models.items():
    # Train the model
    model.fit(x_train, y_train)
    
    # Make predictions
    y_pred = model.predict(x_test)
    
    # Evaluate the model
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
      # Store the results
    results.append({
        "model": name,
        "mse": mse,
        "rmse": rmse,
        "mae": mae,
        "r2": r2
    })
    
    y_pred = model.predict([[42.049999,45.000000,38.000000,38.230000,38.189480,2012,18,5]])
    print(f'{name}:')
    print('------------------------------------')
    print("predicted volume:",y_pred)
    print('------------------------------------')
    print(f'Mean Squared Error (MSE): {mse}')
    print(f'Root Mean Squared Error (RMSE): {rmse}')
    print(f'Mean Absolute Error (MAE): {mae}')
    print(f'R-squared (R2): {r2}')
    print('------------------------------------')
# Out:
# C:\Users\SMARTECH\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning:
#
# X does not have valid feature names, but LinearRegression was fitted with feature names
# Linear Regression:
# ------------------------------------
# predicted volume: [67514514.78635502]
# ------------------------------------
# Mean Squared Error (MSE): 1029225357731226.4
# Root Mean Squared Error (RMSE): 32081542.321578406
# Mean Absolute Error (MAE): 14501143.082898911
# R-squared (R2): 0.21769515159719288
# ------------------------------------
# C:\Users\SMARTECH\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning:
#
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#
# C:\Users\SMARTECH\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning:
#
# X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
# Random Forest:
# ------------------------------------
# predicted volume: [72201208.]
# ...

# %%
results_df = pd.DataFrame(results)
# print(results_df)
best_model = results_df.loc[results_df['rmse'].idxmin()]["model"]
print("----------------------------------------------------------------------")
print("----------------------------------------------------------------------")
print(f"The best model based on RMSE is: {best_model}")
# Out:
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# The best model based on RMSE is: Random Forest

# %%
# prediction with random forest

# %%
random_pred=RandomForestRegressor(random_state=42)
random_pred.fit(x_train,y_train)
values=pd.DataFrame([[42.049999,45.000000,38.000000,38.230000,38.189480,2012,18,5]], columns=x_train.columns)
predicted_value=random_pred.predict(values)
print("predicted value with random forest is",predicted_value)
# Out:
# predicted value with random forest is [72201208.]
